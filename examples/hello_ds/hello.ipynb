# %%
import pandas as pd
import numpy as np
data = pd.read_csv('data.csv')

# %%
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
data.replace({'male': 1, 'female': 0}, inplace=True)

# %%
data.corr(numeric_only=True).abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055512
# sibsp     0.027825
# parch     0.082660
# fare      0.244265
# body           NaN

# %%
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr(numeric_only=True).abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055512
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# body            NaN
# relatives  0.201719

# %%
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
# Out:
# 2023-12-15 09:20:11.206127: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-15 09:20:11.544146: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-15 09:20:11.544214: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-15 09:20:11.614986: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-15 09:20:11.759193: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-15 09:20:11.761279: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-15 09:20:13.352044: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5)                 30
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 66 (264.00 Byte)
# Trainable params: 66 (264.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 1s 3ms/step - loss: 0.6927 - accuracy: 0.5431
# Epoch 2/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6910 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6883 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6815 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6680 - accuracy: 0.5861
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6466 - accuracy: 0.5861
# Epoch 7/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6204 - accuracy: 0.6890
# Epoch 8/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5926 - accuracy: 0.7751
# Epoch 9/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5689 - accuracy: 0.7811
# Epoch 10/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5489 - accuracy: 0.7787
# Epoch 11/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5310 - accuracy: 0.7871
# Epoch 12/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5179 - accuracy: 0.7775
# Epoch 13/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.7835
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.7763
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4921 - accuracy: 0.7751
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.7775
# Epoch 17/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.7763
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4804 - accuracy: 0.7763
# Epoch 19/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4772 - accuracy: 0.7787
# Epoch 20/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4740 - accuracy: 0.7823
# Epoch 21/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.7847
# Epoch 22/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4687 - accuracy: 0.7835
# Epoch 23/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4671 - accuracy: 0.7859
# Epoch 24/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4655 - accuracy: 0.7811
# Epoch 25/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.7835
# Epoch 26/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4624 - accuracy: 0.7847
# Epoch 27/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4618 - accuracy: 0.7811
# Epoch 28/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4607 - accuracy: 0.7835
# Epoch 29/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4594 - accuracy: 0.7811
# Epoch 30/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.7847
# Epoch 31/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4574 - accuracy: 0.7847
# Epoch 32/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4567 - accuracy: 0.7859
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4556 - accuracy: 0.7847
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4547 - accuracy: 0.7835
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4541 - accuracy: 0.7871
# Epoch 36/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4534 - accuracy: 0.7847
# Epoch 37/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.7835
# Epoch 38/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.7847
# Epoch 39/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4518 - accuracy: 0.7823
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4511 - accuracy: 0.7835
# Epoch 41/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4503 - accuracy: 0.7835
# Epoch 42/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4499 - accuracy: 0.7859
# Epoch 43/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4498 - accuracy: 0.7835
# Epoch 44/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4495 - accuracy: 0.7859
# Epoch 45/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.7811
# Epoch 46/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4492 - accuracy: 0.7823
# Epoch 47/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.7799
# Epoch 48/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4489 - accuracy: 0.7847
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4480 - accuracy: 0.7847
# Epoch 50/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4478 - accuracy: 0.7859

# %%
y_pred = np.rint(model.predict(X_test).flatten())
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 7/7 [==============================] - 0s 2ms/step
# 0.7942583732057417
